# %%
import os
from os.path import isfile, join
import shutil
from imageai.Detection import ObjectDetection
# Out:
# Using TensorFlow backend.

# %%
from tqdm import tqdm
import time
#for i in tqdm(range(100)):
#    time.sleep(0.5)

# %%
execution_path = os.getcwd()
foodd_dir = '''D:\PROGRAMMING_PROJS\FooDMachineLearning\FooDD'''
dest_dir = '''D:\PROGRAMMING_PROJS\FooDMachineLearning\FoodMLrepo\FoodML\images'''
ecustfd_dir = '''D:\PROGRAMMING_PROJS\FooDMachineLearning\ECUSTFD-resized--master\JPEGImages'''
os.listdir(foodd_dir)
def findfiles(rootpath):
    fillist = []
    for subel in os.listdir(rootpath):
        if isfile(join(rootpath,subel)):
            #print(join(rootpath,subel))
            fillist.append(join(rootpath,subel))
        else:
            fillist.extend(findfiles(join(rootpath,subel)))
    return fillist
foodd_list = findfiles(foodd_dir)
print(foodd_list)
# Out:
# ['D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\FooDD\\Apple\\1-Samsung-S4-Light Environment\\1 (1).jpg', 'D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\FooDD\\Apple\\1-Samsung-S4-Light Environment\\1 (20).jpg', 'D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\FooDD\\Apple\\1-Samsung-S4-Light Environment\\1 (21).jpg', 'D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\FooDD\\Apple\\1-Samsung-S4-Light Environment\\1 (22).jpg', 'D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\FooDD\\Apple\\1-Samsung-S4-Light Environment\\1 (23).jpg', 'D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\FooDD\\Apple\\1-Samsung-S4-Light Environment\\1 (24).jpg', 'D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\FooDD\\Apple\\1-Samsung-S4-Light Environment\\1 (25).jpg', 'D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\FooDD\\Apple\\1-Samsung-S4-Light Environment\\1 (26).jpg', 'D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\FooDD\\Apple\\1-Samsung-S4-Light Environment\\1 (27).jpg', 'D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\FooDD\\Apple\\1-S
# ...

# %%
len(foodd_list)
# Out:
# 3887

# %%
ecustfd_dir = '''D:\PROGRAMMING_PROJS\FooDMachineLearning\ECUSTFD-resized--master\JPEGImages'''
ecustfd_list = findfiles(ecustfd_dir)
print(ecustfd_list)
# Out:
# ['D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\ECUSTFD-resized--master\\JPEGImages\\apple001S(1).JPG', 'D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\ECUSTFD-resized--master\\JPEGImages\\apple001S(2).JPG', 'D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\ECUSTFD-resized--master\\JPEGImages\\apple001T(1).JPG', 'D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\ECUSTFD-resized--master\\JPEGImages\\apple001T(2).JPG', 'D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\ECUSTFD-resized--master\\JPEGImages\\apple002S(1).JPG', 'D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\ECUSTFD-resized--master\\JPEGImages\\apple002S(2).JPG', 'D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\ECUSTFD-resized--master\\JPEGImages\\apple002S(3).JPG', 'D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\ECUSTFD-resized--master\\JPEGImages\\apple002S(4).JPG', 'D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\ECUSTFD-resized--master\\JPEGImages\\apple002S(5).JPG', 'D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\ECUSTFD-resized--master\\JPEGImages\\apple0
# ...

# %%
len(ecustfd_list)
# Out:
# 2978

# %%
import pandas as pd
foodd_pd = pd.DataFrame(foodd_list,columns=['Full Path'])
foodd_pd.head()
# Out:
#                                            Full Path
# 0  D:\PROGRAMMING_PROJS\FooDMachineLearning\FooDD...
# 1  D:\PROGRAMMING_PROJS\FooDMachineLearning\FooDD...
# 2  D:\PROGRAMMING_PROJS\FooDMachineLearning\FooDD...
# 3  D:\PROGRAMMING_PROJS\FooDMachineLearning\FooDD...
# 4  D:\PROGRAMMING_PROJS\FooDMachineLearning\FooDD...

# %%
foodd_pd['W/o common'] = foodd_pd['Full Path'].apply(lambda x: x.replace(foodd_dir+'\\',''))
foodd_pd
# Out:
#                                               Full Path  \
# 0     D:\PROGRAMMING_PROJS\FooDMachineLearning\FooDD...
# 1     D:\PROGRAMMING_PROJS\FooDMachineLearning\FooDD...
# 2     D:\PROGRAMMING_PROJS\FooDMachineLearning\FooDD...
# 3     D:\PROGRAMMING_PROJS\FooDMachineLearning\FooDD...
# 4     D:\PROGRAMMING_PROJS\FooDMachineLearning\FooDD...
# 5     D:\PROGRAMMING_PROJS\FooDMachineLearning\FooDD...
# 6     D:\PROGRAMMING_PROJS\FooDMachineLearning\FooDD...
# 7     D:\PROGRAMMING_PROJS\FooDMachineLearning\FooDD...
# 8     D:\PROGRAMMING_PROJS\FooDMachineLearning\FooDD...
# 9     D:\PROGRAMMING_PROJS\FooDMachineLearning\FooDD...
# 10    D:\PROGRAMMING_PROJS\FooDMachineLearning\FooDD...
# 11    D:\PROGRAMMING_PROJS\FooDMachineLearning\FooDD...
# 12    D:\PROGRAMMING_PROJS\FooDMachineLearning\FooDD...
# 13    D:\PROGRAMMING_PROJS\FooDMachineLearning\FooDD...
# 14    D:\PROGRAMMING_PROJS\FooDMachineLearning\FooDD...
# 15    D:\PROGRAMMING_PROJS\FooDMachineLearning\FooDD...
# ...

# %%
all_list = foodd_list
all_list.extend(ecustfd_list)
print(all_list)
# Out:
# ['D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\FooDD\\Apple\\1-Samsung-S4-Light Environment\\1 (1).jpg', 'D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\FooDD\\Apple\\1-Samsung-S4-Light Environment\\1 (20).jpg', 'D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\FooDD\\Apple\\1-Samsung-S4-Light Environment\\1 (21).jpg', 'D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\FooDD\\Apple\\1-Samsung-S4-Light Environment\\1 (22).jpg', 'D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\FooDD\\Apple\\1-Samsung-S4-Light Environment\\1 (23).jpg', 'D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\FooDD\\Apple\\1-Samsung-S4-Light Environment\\1 (24).jpg', 'D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\FooDD\\Apple\\1-Samsung-S4-Light Environment\\1 (25).jpg', 'D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\FooDD\\Apple\\1-Samsung-S4-Light Environment\\1 (26).jpg', 'D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\FooDD\\Apple\\1-Samsung-S4-Light Environment\\1 (27).jpg', 'D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\FooDD\\Apple\\1-S
# ...

# %%
len(all_list)
# Out:
# 6865

# %%
import cv2
filename = 'your_image.jpg'
W = 1000.
out_dir = join('D:','\\','PROGRAMMING_PROJS','FooDMachineLearning','dataset_resiz')
cnt = 0
#for fili in tqdm(foodd_list):
#    filparts = fili.split('\\')
#    fil = join(filparts[0],'\\')
#    for fi in filparts[1:]:
#        fil = join(fil,fi)
#    outp = join(out_dir,(str(cnt)+fil.replace('\\','_').replace('.','_').replace('D:','')+os.path.basename(fil)).replace(' ','__'))
#    oriimg = cv2.imread(fil,cv2.IMREAD_COLOR)
#    try:
#        height, width, depth = oriimg.shape
#        imgScale = 200./width
#        newX,newY = oriimg.shape[1]*imgScale, oriimg.shape[0]*imgScale
#        newimg = cv2.resize(oriimg,(int(newX),int(newY)))
#        cv2.imwrite(outp.replace('\\','/'),newimg)
#        cnt+=1
#    except AttributeError:
#        print('Couldn\'t be resized: ', fil)

# %%
from imageai.Detection import ObjectDetection
import os
#out_dir = '''D:\PROGRAMMING_PROJS\FooDMachineLearning\dataset2'''
execution_path = os.getcwd()
detector = ObjectDetection()
detector.setModelTypeAsRetinaNet()
detector.setModelPath(os.path.join(execution_path, "resnet50_coco_best_v2.0.1.h5"))
detector.loadModel()
#detections = detector.detectObjectsFromImage(input_image="avocado 4.jpg", output_image_path="avocadodec.jpg", extract_detected_objects=True, minimum_percentage_probability=30)
#detections = detector.detectObjectsFromImage(input_image="apple 4.jpg", output_image_path="avocadodec.jpg", minimum_percentage_probability=30)

#for eachObject in detections:
#    print(eachObject["name"] , " : ", eachObject["percentage_probability"], " : ", eachObject["box_points"] )
#    print("--------------------------------")

# %%
def detocbjs(pathslist, outd):
    cnt = 1
    for fil in tqdm(pathslist):
        outp = join(outd,(str(cnt)+os.path.basename(fil)).replace(' ','__'))
        cnt += 1
        print(outp)
        try:
            detections = detector.detectObjectsFromImage(input_image=fil,
                                                 extract_detected_objects=True,
                                                 output_image_path=outp,
                                                 minimum_percentage_probability=30)
        except ValueError:
            print('Value Error occured')
        except SystemError:
            print('System Error occured')

# %%
#out_dir = join('D:','\\','PROGRAMMING_PROJS','FooDMachineLearning','dataset_resiz')
out_dir = '''D:\PROGRAMMING_PROJS\FooDMachineLearning\FooDD\\Net images'''
print(out_dir)
res_list = findfiles(out_dir)
out_dir2 = '''D:\PROGRAMMING_PROJS\FooDMachineLearning\dataset4'''
out_dir
# Out:
# D:\PROGRAMMING_PROJS\FooDMachineLearning\FooDD\Net images
# 'D:\\PROGRAMMING_PROJS\\FooDMachineLearning\\FooDD\\Net images'

# %%
#res_list

# %%
detocbjs(res_list,out_dir2)
# Out:
#   0%|                                                                                          | 0/255 [00:00<?, ?it/s]
# D:\PROGRAMMING_PROJS\FooDMachineLearning\dataset4\1apple__10.jpg
#   0%|▎                                                                                 | 1/255 [00:07<32:46,  7.74s/it]
# D:\PROGRAMMING_PROJS\FooDMachineLearning\dataset4\2apple__11.jpg
#   1%|▋                                                                                 | 2/255 [00:15<31:43,  7.52s/it]
# D:\PROGRAMMING_PROJS\FooDMachineLearning\dataset4\3apple__12.png
#   1%|▉                                                                                 | 3/255 [00:23<32:56,  7.84s/it]
# D:\PROGRAMMING_PROJS\FooDMachineLearning\dataset4\4apple__13.jpg
#   2%|█▎                                                                                | 4/255 [00:34<36:26,  8.71s/it]
# D:\PROGRAMMING_PROJS\FooDMachineLearning\dataset4\5apple__14.jpg
# ...

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread('D:/PROGRAMMING_PROJS/FooDMachineLearning/FooDD/Cucumber/3-IOS-4-Light Environment/3 (18).jpg')
hsv = cv.cvtColor(img,cv.COLOR_BGR2Luv )#cv.COLOR_BGR2YCrCb )
#imshow(hsv)
gray = cv.cvtColor(img,cv.COLOR_RGB2GRAY)
imshow(gray)
ret, thresh = cv.threshold(gray,0,255,cv.THRESH_BINARY_INV+cv.THRESH_OTSU)
out_dir = '''D:\PROGRAMMING_PROJS\FooDMachineLearning\dataset2'''

# %%
# noise removal
kernel = np.ones((3,3),np.uint8)
opening = cv.morphologyEx(thresh,cv.MORPH_OPEN,kernel, iterations = 2)
# sure background area
sure_bg = cv.dilate(opening,kernel,iterations=5)
# Finding sure foreground area
dist_transform = cv.distanceTransform(opening,cv.DIST_L2,5)
ret, sure_fg = cv.threshold(dist_transform,0.7*dist_transform.max(),255,0)
# Finding unknown region
sure_fg = np.uint8(sure_fg)
unknown = cv.subtract(sure_bg,sure_fg)

# %%
# Marker labelling
ret, markers = cv.connectedComponents(sure_fg)
# Add one to all labels so that sure background is not 0, but 1
markers = markers+1
# Now, mark the region of unknown with zero
markers[unknown==255] = 0

# %%
from matplotlib.pyplot import imshow
imshow(markers)

# %%
type(markers)
# Out:
# numpy.ndarray

# %%
markers = cv.watershed(img,markers)
img[markers == -1] = [255,0,0]

# %%
imshow(img)

# %%
img = cv.imread('D:/PROGRAMMING_PROJS/FooDMachineLearning/FooDD/Cucumber/3-IOS-4-Light Environment/ccc.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
import numpy as np
from scipy import ndimage
import matplotlib.pyplot as plt
from sklearn.mixture import GMM
import cv2 as cv

np.random.seed(1)
n = 10
l = 256
im = np.zeros((l, l))
points = l*np.random.random((2, n**2))
im[(points[0]).astype(np.int), (points[1]).astype(np.int)] = 1
im = ndimage.gaussian_filter(im, sigma=l/(4.*n))

mask = (im > im.mean()).astype(np.float)


img = cv.imread('D:/PROGRAMMING_PROJS/FooDMachineLearning/FooDD/Cucumber/3-IOS-4-Light Environment/3 (18).jpg')#mask + 0.3*np.random.randn(*mask.shape)

hist, bin_edges = np.histogram(img, bins=60)
bin_centers = 0.5*(bin_edges[:-1] + bin_edges[1:])

classif = GMM(n_components=2)
classif.fit(img.reshape((img.size, 1)))

threshold = np.mean(classif.means_)
binary_img = img > threshold


plt.figure(figsize=(11,4))

plt.subplot(131)
plt.imshow(img)
plt.axis('off')
plt.subplot(132)
plt.plot(bin_centers, hist, lw=2)
plt.axvline(0.5, color='r', ls='--', lw=2)
plt.text(0.57, 0.8, 'histogram', fontsize=20, transform = plt.gca().transAxes)
plt.yticks([])
plt.subplot(133)
plt.imshow(binary_img, cmap=plt.cm.gray, interpolation='nearest')
plt.axis('off')

plt.subplots_adjust(wspace=0.02, hspace=0.3, top=1, bottom=0.1, left=0, right=1)
plt.show()
# Out:
# C:\Users\AdamT\Anaconda3\envs\foodmlenv\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class GMM is deprecated; The class GMM is deprecated in 0.18 and will be  removed in 0.20. Use class GaussianMixture instead.
#   warnings.warn(msg, category=DeprecationWarning)
# C:\Users\AdamT\Anaconda3\envs\foodmlenv\lib\site-packages\sklearn\utils\deprecation.py:77: DeprecationWarning: Function distribute_covar_matrix_to_match_covariance_type is deprecated; The function distribute_covar_matrix_to_match_covariance_typeis deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# C:\Users\AdamT\Anaconda3\envs\foodmlenv\lib\site-packages\sklearn\utils\deprecation.py:77: DeprecationWarning: Function log_multivariate_normal_density is deprecated; The function log_multivariate_normal_density is deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# ...

# %%
plt.imshow(binary_img)
# Out:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x000001C67BEF5950> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\envs\foodmlenv\lib\site-packages\matplotlib\pyplot.py in post_execute()
#     147             def post_execute():
#     148                 if matplotlib.is_interactive():
# --> 149                     draw_all()
#     150
#     151             # IPython >= 2
#
# ~\Anaconda3\envs\foodmlenv\lib\site-packages\matplotlib\_pylab_helpers.py in draw_all(cls, force)
#     134         for f_mgr in cls.get_all_fig_managers():
#     135             if force or f_mgr.canvas.figure.stale:
# --> 136                 f_mgr.canvas.draw_idle()
#     137
#     138 atexit.register(Gcf.destroy_all)
#
# ~\Anaconda3\envs\foodmlenv\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
# ...
